# %% [markdown]
# # Sibel Cubuk

# %% [markdown]
# <div class="alert alert-block alert-info alert">
#
# # <span style=" color:red">WELCOME!
#
# Welcome to "Bike Demand Visualization Project" which is the capstone project of Data Visualization Lessons . As you know recently, free or affordable access to bicycles has been provided for short-distance trips in an urban area as an alternative to motorized public transport or private vehicles. Thus, it is aimed to reduce traffic congestion, noise and air pollution.
#
# The aim of this project is to reveal the current patterns in the data by showing the historical data of London bike shares with visualization tools.
#
# This will allow us to X-ray the data as part of the EDA process before setting up a machine learning model.</span>

# %% [markdown]
# <div class="alert alert-block alert-success ">
#
# ## <span style=" color:red">Determines
#
# Features
#
# - timestamp - timestamp field for grouping the data
# - cnt - the count of a new bike shares
# - t1 - real temperature in C
# - t2 - temperature in C “feels like”
# - hum - humidity in percentage
# - wind_speed - wind speed in km/h
# - weather_code - category of the weather
# - is_holiday - boolean field - 1 holiday / 0 non holiday
# - is_weekend - boolean field - 1 if the day is weekend
# - season - category field meteorological seasons: 0-spring ; 1-summer; 2-fall; 3-winter.
#
# "weather_code" category description:
#
# - 1 = Clear ; mostly clear but have some values with haze/fog/patches of fog/ fog in vicinity
# - 2 = scattered clouds / few clouds
# - 3 = Broken clouds
# - 4 = Cloudy
# - 7 = Rain/ light Rain shower/ Light rain
# - 10 = rain with thunderstorm
# - 26 = snowfall
# - 94 = Freezing Fog
#
# Initially, the task of discovering data will be waiting for you as always. Recognize features, detect missing values, outliers etc. Review the data from various angles in different time breakdowns. For example, visualize the distribution of bike shares by day of the week. With this graph, you will be able to easily observe and make inferences how people's behavior changes daily. Likewise, you can make hourly, monthly, seasonally etc. analyzes. In addition, you can analyze correlation of variables with a heatmap.
#
# # <span style=" color:red">Tasks
# </span>

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">1. Import Libraries
# </span>

# %%
import numpy as np
import pandas as pd


import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
from pylab import rcParams
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">2. Read Dataset
# </span>

# %%
df=pd.read_csv("store_sharing.csv")
df.head()
# Out:
#              timestamp  cnt   t1   t2    hum  wind_speed  weather_code  \
# 0  2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 1  2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2  2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 3  2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 4  2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#    is_holiday  is_weekend  season
# 0         0.0         1.0     3.0
# 1         0.0         1.0     3.0
# 2         0.0         1.0     3.0
# 3         0.0         1.0     3.0
# 4         0.0         1.0     3.0

# %%
df.info()
# timestamp may need to convert to the datatime type in future
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  object
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  float64
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 1.3+ MB

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">3. Check missing values and if there are any dublicate rows or not.
# </span>

# %%
df.isnull().sum()
# there is no any null values
# Out:
# timestamp       0
# cnt             0
# t1              0
# t2              0
# hum             0
# wind_speed      0
# weather_code    0
# is_holiday      0
# is_weekend      0
# season          0
# dtype: int64

# %%
df.duplicated().sum()
# there is no any duplicate
# Out:
# 0

# %%
## df.reset_index(drop=True,inplace=True) -- After removing dupl. rows,the index may have gaps

# %%
df = df.rename(columns={'hum':'humidity',
                       'cnt':'count'})
# I changed the 2 columns name
df.head()
# Out:
#              timestamp  count   t1   t2  humidity  wind_speed  weather_code  \
# 0  2015-01-04 00:00:00    182  3.0  2.0      93.0         6.0           3.0
# 1  2015-01-04 01:00:00    138  3.0  2.5      93.0         5.0           1.0
# 2  2015-01-04 02:00:00    134  2.5  2.5      96.5         0.0           1.0
# 3  2015-01-04 03:00:00     72  2.0  2.0     100.0         0.0           1.0
# 4  2015-01-04 04:00:00     47  2.0  0.0      93.0         6.5           1.0
#
#    is_holiday  is_weekend  season
# 0         0.0         1.0     3.0
# 1         0.0         1.0     3.0
# 2         0.0         1.0     3.0
# 3         0.0         1.0     3.0
# 4         0.0         1.0     3.0

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">4. Plot the distribution of various discrete features on (Season, haliday, weekend and weathercode)
# </span>

# %%
# usually use displot,histplot,kddeplot for distribution

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x=df.season,palette="coolwarm" )
plt.title('Distribution of Seasons')
plt.xlabel('Season')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x=df.is_holiday )
plt.title('Distribution of Holiday')
plt.xlabel('Holiday')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x=df.is_weekend, palette="Spectral")
plt.title('Distribution of Weekend')
plt.xlabel('Weekend')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x=df.weather_code , palette="icefire")
plt.title('Distribution of Weather')
plt.xlabel('Weather')
plt.ylabel('Count')
plt.show()

# %%
# We may see all of them at one time

fig,ax=plt.subplots(2,2, figsize=(10,10))
sns.countplot(df,x="season",ax=ax[0][0])
ax[0][0].set_xlabel("Season")
ax[0][0].set_ylabel("Count")
ax[0][0].set_title("Distribution of Seasons")

sns.countplot(df,x="is_holiday",ax=ax[0][1])
ax[0][1].set_xlabel("Holiday")
ax[0][1].set_ylabel("Count")
ax[0][1].set_title("Distribution of Holiday")

sns.countplot(df,x="is_weekend",ax=ax[1][0])
ax[1][0].set_xlabel("Weekend")
ax[1][0].set_ylabel("Count")
ax[1][0].set_title("Distribution of Weekend")

sns.countplot(df,x="weather_code",ax=ax[1][1])
ax[1][1].set_xlabel("Weather Code")
ax[1][1].set_ylabel("Count")
ax[1][1].set_title("Distribution of Weather Code")


fig.tight_layout()
plt.show()

# %% [markdown]
# # weather_code
# sns.countplot(x='weather_code',data=df)
#
# 1 = Clear ; mostly clear but have some values with haze/fog/patches of fog/ fog in vicinity
# 2 = scattered clouds / few clouds
# 3 = Broken clouds
# 4 = Cloudy
# 7 = Rain/ light Rain shower/ Light rain
# 10 = rain with thunderstorm
# 26 = snowfall
# 94 = Freezing Fog

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">5. Look at the data type of each variable, transform timestamp in type, and set it as index.
# </span>

# %%
df.info() # cheached the data type of all columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  object
#  1   count         17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   humidity      17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  float64
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 1.3+ MB

# %%
# transform timestamp in type
df["timestamp"] = pd.to_datetime(df["timestamp"])

# %%
df.set_index('timestamp', inplace= True) # set the index with timestamp columns

# %%
df.tail(2)
# Out:
#                      count   t1   t2  humidity  wind_speed  weather_code  \
# timestamp
# 2017-01-03 22:00:00    224  5.5  1.5      76.0        23.0           4.0
# 2017-01-03 23:00:00    139  5.0  1.0      76.0        22.0           2.0
#
#                      is_holiday  is_weekend  season
# timestamp
# 2017-01-03 22:00:00         0.0         0.0     3.0
# 2017-01-03 23:00:00         0.0         0.0     3.0

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">6. Make feature engineering. Extract new columns (day of the week, day of the month, hour, month, season, year etc.)
# </span>

# %% [markdown]
# ![Screenshot%202021-10-27%20164721.png](attachment:Screenshot%202021-10-27%20164721.png)

# %%
# convert index column to datetime type
df.index = pd.to_datetime(df.index)

# %% [markdown]
# # https://www.programiz.com/python-programming/datetime/strftime

# %%
df["year_month"] = df.index.strftime('%Y-%m')
df['year']=df.index.year
df['month']=df.index.month
df['day']=df.index.day
df['day_of_week']=df.index.dayofweek
df['hour']=df.index.hour

# %%
df.head()
# Out:
#                      count   t1   t2  humidity  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00    182  3.0  2.0      93.0         6.0           3.0
# 2015-01-04 01:00:00    138  3.0  2.5      93.0         5.0           1.0
# 2015-01-04 02:00:00    134  2.5  2.5      96.5         0.0           1.0
# 2015-01-04 03:00:00     72  2.0  2.0     100.0         0.0           1.0
# 2015-01-04 04:00:00     47  2.0  0.0      93.0         6.5           1.0
#
#                      is_holiday  is_weekend  season year_month  year  month  \
# timestamp
# 2015-01-04 00:00:00         0.0         1.0     3.0    2015-01  2015      1
# 2015-01-04 01:00:00         0.0         1.0     3.0    2015-01  2015      1
# 2015-01-04 02:00:00         0.0         1.0     3.0    2015-01  2015      1
# 2015-01-04 03:00:00         0.0         1.0     3.0    2015-01  2015      1
# 2015-01-04 04:00:00         0.0         1.0     3.0    2015-01  2015      1
#
#                      day  day_of_week  hour
# ...

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">7. Visualize the correlation with a heatmap
# </span>

# %%
plt.figure(figsize=(15,12))
sns.heatmap(df.corr(),annot=True,cmap="cubehelix")
plt.title("Heatmap of Correlation");

# %%
df.corr()
# Out:
#                  count        t1        t2  humidity  wind_speed  \
# count         1.000000  0.388798  0.369035 -0.462901    0.116295
# t1            0.388798  1.000000  0.988344 -0.447781    0.145471
# t2            0.369035  0.988344  1.000000 -0.403495    0.088409
# humidity     -0.462901 -0.447781 -0.403495  1.000000   -0.287789
# wind_speed    0.116295  0.145471  0.088409 -0.287789    1.000000
# weather_code -0.166633 -0.097114 -0.098385  0.334750    0.124803
# is_holiday   -0.051698 -0.042233 -0.040051  0.032068   -0.002606
# is_weekend   -0.096499 -0.005342 -0.008510  0.028098    0.011479
# season       -0.116180 -0.285851 -0.285900  0.290381    0.010305
# year          0.010046 -0.037959 -0.044972  0.072443   -0.094739
# month         0.063757  0.332712  0.368366  0.113149   -0.086383
# day          -0.017887  0.005072  0.006791 -0.020868    0.002040
# day_of_week  -0.068688 -0.002317 -0.006824  0.011556    0.001708
# ...

# %%
# target corr with other features
#target_corr=df.corr().count.drop("count")

# %%
# for the target variable(count)
plt.figure(figsize=(6,6))
sns.heatmap(df.corr()[["count"]].sort_values(by="count",ascending=False), cmap="rocket", annot=True, center=1, vmin =-1);

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">8. Visualize the correlation of the target variable and the other features with barplot
# </span>

# %%
plt.figure(figsize=(10,8))
df.corr()["count"].sort_values().plot.barh();

# %% [markdown]
# ![Screenshot%202021-10-27%20170237.png](attachment:Screenshot%202021-10-27%20170237.png)

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">9. Plot bike shares over time use lineplot.
# </span>

# %%
df.plot.line( y='count', figsize=(15, 6), legend=False, color="purple")
plt.xticks(rotation=45, size = 10)
plt.title("Bikes Shares Over Time ");

# %%
# There are two outlier on 2015

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">10. Plot bike shares by months and year_of_month (use lineplot, pointplot, barplot).
# </span>

# %%
df.head()
# Out:
#                      count   t1   t2  humidity  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00    182  3.0  2.0      93.0         6.0           3.0
# 2015-01-04 01:00:00    138  3.0  2.5      93.0         5.0           1.0
# 2015-01-04 02:00:00    134  2.5  2.5      96.5         0.0           1.0
# 2015-01-04 03:00:00     72  2.0  2.0     100.0         0.0           1.0
# 2015-01-04 04:00:00     47  2.0  0.0      93.0         6.5           1.0
#
#                      is_holiday  is_weekend  season year_month  year  month  \
# timestamp
# 2015-01-04 00:00:00         0.0         1.0     3.0    2015-01  2015      1
# 2015-01-04 01:00:00         0.0         1.0     3.0    2015-01  2015      1
# 2015-01-04 02:00:00         0.0         1.0     3.0    2015-01  2015      1
# 2015-01-04 03:00:00         0.0         1.0     3.0    2015-01  2015      1
# 2015-01-04 04:00:00         0.0         1.0     3.0    2015-01  2015      1
#
#                      day  day_of_week  hour
# ...

# %%
df.groupby("year_month")[["count"]].sum()
# Out:
#               count
# year_month
# 2015-01      546639
# 2015-02      543594
# 2015-03      695934
# 2015-04      831582
# 2015-05      895413
# 2015-06     1033252
# 2015-07     1120687
# 2015-08     1033951
# 2015-09      892478
# 2015-10      865046
# 2015-11      677332
# 2015-12      602838
# 2016-01      582518
# 2016-02      592910
# 2016-03      656527
# 2016-04      768845
# 2016-05     1001935
# 2016-06      933878
# 2016-07     1165527
# 2016-08     1137314
# 2016-09      998619
# 2016-10      935706
# 2016-11      703859
# 2016-12      651908
# 2017-01       37680

# %%
## pd.set_option('display.max_columns',None)
## df.head()

# %%
plt.figure(figsize=(15,5))
sns.lineplot(data = df.groupby("year_month")[["count"]].sum(), x = 'year_month', y = 'count')
plt.xticks(rotation = 45)
plt.xlabel('YEAR', size = 12)
plt.ylabel('COUNT',size = 12);

# %%
# line plot
plt.figure(figsize=(10,5))
sns.lineplot(df,x="month",y="count")
plt.xlabel('MONTH', size = 12)
plt.ylabel('COUNT',size = 12);

# %%
# point plot
plt.figure(figsize=(10,5))
sns.pointplot(df,x="month",y="count")
plt.xlabel('MONTH', size = 12)
plt.ylabel('COUNT',size = 12);

# %%
# barplot
plt.figure(figsize=(10,5))
sns.barplot(df,x="month",y="count" , palette="Spectral")
plt.title("Bike Shares by Month")
plt.xlabel('MONTH', size = 12)
plt.ylabel('COUNT',size = 12);

# %%
plt.figure(figsize=(20,6))
sns.barplot(df,x="year_month",y="count" , palette="Spectral")
plt.title("Bike Shares by Year-Month")
plt.xticks(rotation=45)
plt.xlabel('MONTH', size = 12)
plt.ylabel('COUNT',size = 12);

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">11. Plot bike shares by hours on (holidays, weekend, season).
# </span>

# %%
## checking is holiday or not with lineplot
plt.figure(figsize=(15,5))
sns.lineplot(df, x = 'hour', y = 'count', hue="is_holiday",palette="magma")
plt.xlabel('HOUR', size = 12)
plt.ylabel('COUNT',size = 12);

# %%
season_mapping = {0.0: 'Spring', 1.0: 'Summer', 2.0: 'Autumn', 3.0: 'Winter'}
df['season_name'] = df['season'].replace(season_mapping)

# %%
## checking for season  with lineplot
plt.figure(figsize=(15,5))
sns.lineplot(df, x = 'hour', y = 'count', hue="season_name",palette="viridis")
plt.xlabel('HOUR', size = 12)
plt.ylabel('COUNT',size = 12);

# %%
## checking for weekend  with lineplot
plt.figure(figsize=(15,5))
sns.lineplot(df, x = 'hour', y = 'count', hue="is_weekend",palette="flare")
plt.xlabel('HOUR', size = 12)
plt.ylabel('COUNT',size = 12);

# %%
## with pointplot
fig, [ax0,ax1,ax2,ax3] = plt.subplots(4,1)
fig.set_size_inches([18,15])
sns.pointplot(data=df, x = 'hour', y = 'count', ax = ax0)
sns.pointplot(data=df, x = 'hour', y = 'count', hue = 'is_holiday',palette="cubehelix", ax = ax1)
sns.pointplot(data=df, x = 'hour', y = 'count', hue = 'is_weekend',palette="flare", ax = ax2)
sns.pointplot(data=df, x = 'hour', y = 'count', hue = 'season_name',palette="viridis", ax = ax3);

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red"> 12. Plot bike shares by day of week.
#
# - You may want to see whether it is a holiday or not
# </span>

# %%
# with barplot
sns.catplot(data=df, x = 'day_of_week', y = 'count', hue = 'is_weekend' , kind = "bar", legend_out=False, palette="viridis")
fig.set_figwidth(5)
fig.set_figheight(5);

# %%
sns.catplot(data=df, x = 'day_of_week', y = 'count', hue = 'is_holiday' , kind = "bar", legend_out=False, palette="viridis")
fig.set_figwidth(5)
fig.set_figheight(5);

# %%
sns.catplot(data=df, x = 'day_of_week', y = 'count', hue = 'season' , kind ="bar" , legend_out=False, palette="viridis")
fig.set_figwidth(5)
fig.set_figheight(5);

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red"> 13. Plot bike shares by day of month
# </span>

# %%
plt.figure(figsize=(20,6))
sns.pointplot(data=df,x="day",y="count",markers="x")
plt.title("Bike shares by Day of Month")
plt.show()

# %%
plt.figure(figsize=(20,6))
sns.barplot(data=df,x="day",y="count")
plt.title("Bike shares by Day of Month")
plt.show()

# %%
# lineplot
plt.figure(figsize=(12,4))
sns.lineplot(df,x="day",y="count");

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red"> 14. Plot bike shares by year
#
# - Plot bike shares on holidays by seasons
# </span>

# %%
plt.figure(figsize=(15,5))
sns.boxenplot(df,x="year",y="count",palette="coolwarm")
plt.title("Bike Shares by Year");

# %%
df[df["year"]==2015]["count"].mean()
# Out:
# 1126.7784334143237

# %%
plt.figure(figsize=(10,5))
ax=sns.barplot(df,x="year",y="count",palette="Spectral",errorbar=None)
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2, height, int(height), ha='center', va='bottom');

# %%
# with barplot
plt.figure(figsize=(8,5))
ax=sns.barplot(data=df[df.is_holiday == 1 ][['count','season']], x = 'season', y = 'count', palette="coolwarm",errorbar=None)
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width() / 2, height, int(height), ha='center', va='bottom');

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">15. Visualize the distribution of bike shares by weekday/weekend with piechart and barplot
# </span>

# %%
df.groupby("is_weekend")["count"].sum()
# Out:
# is_weekend
# 0.0    15048216
# 1.0     4857756
# Name: count, dtype: int64

# %%
plt.subplot(121)
sns.barplot(df,x="is_weekend",y="count",errorbar=None)
plt.ylabel("Bike Shares By Weekdays")
plt.subplot(122)
plt.pie(df.groupby("is_weekend")["count"].sum(),labels=["weekdays","weekdend"],explode=[0.1,0.1],autopct="%1.1f%%")
plt.show()

# %%
df.head()
# Out:
#                      count   t1   t2  humidity  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00    182  3.0  2.0      93.0         6.0           3.0
# 2015-01-04 01:00:00    138  3.0  2.5      93.0         5.0           1.0
# 2015-01-04 02:00:00    134  2.5  2.5      96.5         0.0           1.0
# 2015-01-04 03:00:00     72  2.0  2.0     100.0         0.0           1.0
# 2015-01-04 04:00:00     47  2.0  0.0      93.0         6.5           1.0
#
#                      is_holiday  is_weekend  season year_month  year  month  \
# timestamp
# 2015-01-04 00:00:00         0.0         1.0     3.0    2015-01  2015      1
# 2015-01-04 01:00:00         0.0         1.0     3.0    2015-01  2015      1
# 2015-01-04 02:00:00         0.0         1.0     3.0    2015-01  2015      1
# 2015-01-04 03:00:00         0.0         1.0     3.0    2015-01  2015      1
# 2015-01-04 04:00:00         0.0         1.0     3.0    2015-01  2015      1
#
# ...

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">16. Plot the distribution of weather code by seasons
# </span>

# %%
fig,plt.subplots(figsize=(10,6))
sns.barplot(df,x="weather_code",y="count",hue="season_name",palette="cubehelix",ci=False)
plt.title("Weather Code by Season for Bike Share")
plt.legend(loc="upper right");

# %%
sns.catplot(data=df,x="weather_code", y="count", col="season_name", kind="bar", estimator="sum");

# %%
sns.catplot(data=df,x="weather_code", y="count", col="season_name", kind="bar", estimator="mean");

# %% [markdown]
# <div class="alert alert-info alert-info ">
#
# # <span style=" color:red">Conclusions
#
#
#
#
# </span>

# %% [markdown]
# There is an increase in the use of bicycles in the summer months. The reasons for this can be said to be the  schools closing  and the arrival of more tourists. When we look at the other seasons, considering the weather conditions, it is seen that the usage is intense. In general, there is a density in the departure and arrival times. In order to increase the use of bicycles, more discounts can be made by considering the weather conditions.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <span style=" color:red">Thanks for Attending!..
#
#
# </span>

# %% [markdown]
# ![yaz%C4%B1.webp](attachment:yaz%C4%B1.webp)
